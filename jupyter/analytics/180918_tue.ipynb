# %% [markdown]
# ## Z score
#
# ### 분산
# + 1:68%
# + 2: 95%
# + 3: 99%
#
# ## Sampling Distribution
#
# + 1) probability sampling
#         + "구한 sampling 성질이 population 특성을 따라간다."
#
# + 2) non_probability sampling
#
# ----------------------------
# + 샘플링의 관건: n(몇명을 뽑을 것인가)
# $ \mu = 100$
#
# if n = len(population)
#
# standard_deviation = 0
#
# if n = 1
#
# 평균 중심 sd, n 이커질수록 x축 min/max 점점 줄어들고 y축은 높아진다.
# 결국 population  크기만큼 커지면, 중심 mean값에 모든 값들이 몰리는 현상이 만들어진다.
#
#
# 샘플 평균들의 평균은 = 모집단의 평균
#
# n = 1600
# -> 스몰시그마 = 시그마/sqrt(n)
#
# 이 값들을 활용하면, 68, 95, 99를 사용해서 분포의 퍼센트를 알아낼 수 있다.
#
# ---------------------------------------
# 활용법)
# iq 높아지는 약, 아주대 학생들 10000명, 약먹을 사람 100명, sample뽑을것 100명
#
# 약안먹은 population에서 100 명 sampling 한 녀석의 평균 범위에 약먹은 100명의 평균이 소속되어있으면 안된다.
#
# ----------------------------
# 활용법2)
# 네이버 ui 사용자 평가
#
# 네이버 사용자 평가 평균 60, sd = 8이었을때, 내가 네이버에 입사하여 네이버 ui를 갈았을 때 25명에게 사용자 평가를 측정하라했을때 65점
#
# 샘플 분포의 평균 60, sd = 8/5 99%치가 24/5 = 약 4.몇
# 즉 64.x가 나올 확률이 99%이고 65점이 나오기 위해서는 1%확률로 나올 수 있는데, 즉 100번 하여 1번 나올까말까 하는데 제가 25명 상대로 그 값을 이끌어 내었습니다.
#
# -------------------
# ### central Limit Themorem(CLT)
#
# 샘플 평균들의 sd = (샘플 평균들의) `standard error(표준 오차)`
#
# -----------------------
#
# 가설 (차이의 가설)
# $\bar{x} != \mu$
# 112, 100 나옴(4명 sample)
#
# IF, $\bar{x} = \mu$ 이면, 90 - 110이 95%이고 내 평균은 112 인데 내 성적은 5%의 확률로 나왔다고 해석할 수 있고, 다른 해석으로는 약이 효과가 있다라고 평가할 수 있다.
#
#
# 샘플 숫자가 작다면 se(standard error)
# 샘플 숫자가 엄청 커져서 거의 population에 가까워지면 se(standard error) = 0 이 되어
# 실제 평균에 가까워지게 된다.
#
# 샘플의 숫자가 일정 명이상이 된다면, n에 대한 se의 크기 감소가 점점 작게 감소된다.
#
# 교수님 아까 약품같은 성능 테스트를 할때 그럼 샘플수를 올리면 se가 작아져서 얻은 점수가
#
#
# ---------------------------
#
# Q) 확률조작 가능하지 않는가?
# 근데 sample이 작아지면, sample하였을때 평균값이 부정확하게 나온다. 샘플의 갯수가 작아지면 작아질수록 standard error값이 커지게 된다. (아직 명확하진 않지만, 정확도를 측정하는 계산법이 있어서, 적절한 sample갯수를 구하는 수학 공식? 이 있을것이라 판단됨)
